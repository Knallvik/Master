# %% [markdown]
# # ABEL linac tracking example
#
# By Carl A. Lindstrøm (University of Oslo), 8 Sep 2023

# %% [markdown]
# ### Import ABEL framework

# %%
import time
start = time.time()

import sys
sys.path.append('../../ABEL/')
from abel import *
end = time.time()
print(end-start, ' sek')

import numpy as np
import scipy.constants as SI 
import abel.utilities.plasma_physics as pp

# %load_ext autoreload
# %autoreload 2
# Out:
# 22.790748119354248  sek

# %% [markdown]
# ### Define the linac and beams

# %%
# define driver
driver = SourceBasic()
driver.charge = -2.7e10 * SI.e # [C]
driver.energy = 31.25e9 # [eV]
driver.rel_energy_spread = 0.01
driver.bunch_length = 50e-6 # [m]
driver.z_offset = 580e-6 # [m]
driver.emit_nx, driver.emit_ny = 80e-6, 80e-6 # [m rad]
driver.beta_x, driver.beta_y = 5, 5 #30e-3, 30e-3 # [m]
driver.num_particles = 100000
driver.jitter.x = 0 # [m] 2e-6
driver.jitter.y = 0 # [m] 100e-9
driver.jitter.t = 0 # 10e-15 # [m]
driver.symmetrize = True
#drive_beam = driver.track()  # Convert a Source object to a Beam object.  ######


# define stage
stage = StageQuasistatic2d()
#stage = StagePrtclTransWakeInstability()                      #######
#stage.drive_beam = drive_beam                                 #######
stage.driver_source = driver
stage.length = 11 # [m]
stage.nom_energy_gain = 31.9e9 # [eV]
stage.plasma_density = 2e21 # [m^-3]
stage.ramp_beta_mag = 5
stage.enable_radiation_reaction = True
stage.save_evolution = False
if stage.enable_radiation_reaction == False:
    stage.save_evolution = False

# define first stage (half length)
first_stage = StageQuasistatic2d()
#first_stage = StagePrtclTransWakeInstability()                      #######
#first_stage.drive_beam = drive_beam                                 #######
first_stage.driver_source = driver
first_stage.nom_energy_gain = stage.nom_energy_gain/2
first_stage.length = stage.length/2
first_stage.plasma_density = stage.plasma_density
first_stage.ramp_beta_mag = stage.ramp_beta_mag
first_stage.enable_radiation_reaction = stage.enable_radiation_reaction
first_stage.save_evolution = stage.save_evolution

# define beam
source = SourceBasic()
source.charge = -1e10 * SI.e # [C]
source.energy = 5e9 # [eV]
#source.rel_energy_spread = 0.1
source.rel_energy_spread = 0.01
source.bunch_length = 28e-6 # [m]
source.z_offset = 0e-6 # [m]
source.emit_nx, source.emit_ny = 80e-6, 80e-6 # [m rad]
source.beta_x = stage.matched_beta_function(source.energy)
source.beta_y = source.beta_x
print(source.beta_x*np.sqrt(source.emit_nx/(source.energy*SI.e/SI.m_e/SI.c**2)))
source.num_particles = 50000
source.jitter.t = driver.jitter.t
source.symmetrize = True
beam = source.track()

# define interstage
interstage = InterstageBasic()
#interstage = InterstageElegant()
interstage.beta0 = lambda E: stage.matched_beta_function(E)
interstage.dipole_length = lambda E: 1 * np.sqrt(E/10e9) # [m(eV)]
interstage.dipole_field = 1.  # [T]
#interstage.dipole_field = lambda E: np.min([1.0, 100e9/E]) # [T]

# beam delivery system
bds = BeamDeliverySystemBasic()
bds.beta_x, bds.beta_y = 8e-3, 0.4e-3 # [m]
bds.bunch_length = 0.75 * bds.beta_y

# define linac
linac = Linac()
linac.source = source
linac.stage = stage
linac.first_stage = first_stage
linac.interstage = interstage
linac.num_stages: int = 16*3
shots = 1
# Out:
# 7.5152627622447935e-06

# %% [markdown]
# ### Run simulations

# %%
start = time.time()
linac.run(f'linac_round_beam_RR_{stage.enable_radiation_reaction}\
_stages_{linac.num_stages}', num_shots=shots, overwrite=False, parallel=False);
end = time.time()

print((end - start)/60, ' min') # time in minutes
# Out:
# Tracking element 1 (SourceBasic, stage 0, s = 0.0 m, 5.0 GeV, -1.60 nC, 1.0% rms, 80.1/79.8 µm-rad)
# Number of cores: 5
# time =  6.180531978607178  sec
# Tracking element 2 (StageQuasistatic2d, stage 1, s = 5.5 m, 21.0 GeV, -1.60 nC, 3.1% rms, 80.5/80.7 µm-rad)
# Tracking element 3 (InterstageBasic, stage 1, s = 12.4 m, 21.0 GeV, -1.60 nC, 3.1% rms, 80.6/80.7 µm-rad)
# Number of cores: 5
# time =  5.880753040313721  sec
# Tracking element 4 (StageQuasistatic2d, stage 2, s = 23.4 m, 52.8 GeV, -1.60 nC, 1.5% rms, 80.0/79.8 µm-rad)
# Tracking element 5 (InterstageBasic, stage 2, s = 34.4 m, 52.8 GeV, -1.60 nC, 1.5% rms, 80.0/79.8 µm-rad)
# Number of cores: 5
# time =  3.885624885559082  sec
# Tracking element 6 (StageQuasistatic2d, stage 3, s = 45.4 m, 84.8 GeV, -1.60 nC, 0.8% rms, 80.0/79.8 µm-rad)
# Tracking element 7 (InterstageBasic, stage 3, s = 59.4 m, 84.8 GeV, -1.60 nC, 0.8% rms, 80.0/79.8 µm-rad)
# Number of cores: 5
# time =  3.346572160720825  sec
# Tracking element 8 (StageQuasistatic2d, stage 4, s = 70.4 m, 116.8 GeV, -1.60 nC, 0.5% rms, 80.0/79.7 µm-rad)
# Tracking element 9 (InterstageBasic, stage 4, s = 86.7 m, 116.8 GeV, -1.60 nC, 0.5% rms, 80.0/79.7 µm-rad)
# Number of cores: 5
# time =  2.751730442047119  sec
# Tracking element 10 (StageQuasistatic2d, stage 5, s = 97.7 m, 148.7 GeV, -1.60 nC, 0.4% rms, 79.9/79.7 µm-rad)
# Tracking element 11 (InterstageBasic, stage 5, s = 116.2 m, 148.7 GeV, -1.60 nC, 0.4% rms, 79.9/79.7 µm-rad)
# Number of cores: 5
# time =  2.798144817352295  sec
# Tracking element 12 (StageQuasistatic2d, stage 6, s = 127.2 m, 180.6 GeV, -1.60 nC, 0.4% rms, 79.8/79.6 µm-rad)
# Tracking element 13 (InterstageBasic, stage 6, s = 147.5 m, 180.6 GeV, -1.60 nC, 0.4% rms, 79.8/79.6 µm-rad)
# Number of cores: 5
# time =  2.6588542461395264  sec
# Tracking element 14 (StageQuasistatic2d, stage 7, s = 158.5 m, 212.5 GeV, -1.60 nC, 0.4% rms, 79.8/79.6 µm-rad)
# Tracking element 15 (InterstageBasic, stage 7, s = 180.6 m, 212.5 GeV, -1.60 nC, 0.4% rms, 79.8/79.6 µm-rad)
# Number of cores: 5
# time =  2.8099312782287598  sec
# Tracking element 16 (StageQuasistatic2d, stage 8, s = 191.6 m, 244.4 GeV, -1.60 nC, 0.5% rms, 79.7/79.5 µm-rad)
# Tracking element 17 (InterstageBasic, stage 8, s = 215.2 m, 244.4 GeV, -1.60 nC, 0.5% rms, 79.7/79.5 µm-rad)
# Number of cores: 5
# time =  2.435723066329956  sec
# Tracking element 18 (StageQuasistatic2d, stage 9, s = 226.2 m, 276.1 GeV, -1.60 nC, 0.5% rms, 79.7/79.5 µm-rad)
# Tracking element 19 (InterstageBasic, stage 9, s = 251.4 m, 276.1 GeV, -1.60 nC, 0.5% rms, 79.7/79.5 µm-rad)
# Number of cores: 5
# time =  2.249253034591675  sec
# Tracking element 20 (StageQuasistatic2d, stage 10, s = 262.4 m, 307.9 GeV, -1.60 nC, 0.5% rms, 79.7/79.4 µm-rad)
# Tracking element 21 (InterstageBasic, stage 10, s = 289.0 m, 307.9 GeV, -1.60 nC, 0.5% rms, 79.7/79.4 µm-rad)
# Number of cores: 5
# time =  2.3261191844940186  sec
# Tracking element 22 (StageQuasistatic2d, stage 11, s = 300.0 m, 339.6 GeV, -1.60 nC, 0.4% rms, 79.6/79.4 µm-rad)
# Tracking element 23 (InterstageBasic, stage 11, s = 327.9 m, 339.6 GeV, -1.60 nC, 0.4% rms, 79.6/79.4 µm-rad)
# Number of cores: 5
# time =  2.038486957550049  sec
# Tracking element 24 (StageQuasistatic2d, stage 12, s = 338.9 m, 371.4 GeV, -1.60 nC, 0.4% rms, 79.6/79.3 µm-rad)
# Tracking element 25 (InterstageBasic, stage 12, s = 368.1 m, 371.4 GeV, -1.60 nC, 0.4% rms, 79.6/79.3 µm-rad)
# Number of cores: 5
# time =  1.930635690689087  sec
# Tracking element 26 (StageQuasistatic2d, stage 13, s = 379.1 m, 403.1 GeV, -1.60 nC, 0.4% rms, 79.5/79.3 µm-rad)
# Tracking element 27 (InterstageBasic, stage 13, s = 409.5 m, 403.1 GeV, -1.60 nC, 0.4% rms, 79.5/79.3 µm-rad)
# Number of cores: 5
# time =  1.898085355758667  sec
# Tracking element 28 (StageQuasistatic2d, stage 14, s = 420.5 m, 434.8 GeV, -1.60 nC, 0.4% rms, 79.5/79.2 µm-rad)
# Tracking element 29 (InterstageBasic, stage 14, s = 452.1 m, 434.8 GeV, -1.60 nC, 0.4% rms, 79.5/79.2 µm-rad)
# Number of cores: 5
# time =  1.7943429946899414  sec
# Tracking element 30 (StageQuasistatic2d, stage 15, s = 463.1 m, 466.5 GeV, -1.60 nC, 0.4% rms, 79.4/79.2 µm-rad)
# Tracking element 31 (InterstageBasic, stage 15, s = 495.8 m, 466.5 GeV, -1.60 nC, 0.4% rms, 79.4/79.2 µm-rad)
# Number of cores: 5
# time =  1.7353184223175049  sec
# Tracking element 32 (StageQuasistatic2d, stage 16, s = 506.8 m, 498.2 GeV, -1.60 nC, 0.4% rms, 79.4/79.1 µm-rad)
# Tracking element 33 (InterstageBasic, stage 16, s = 540.7 m, 498.2 GeV, -1.60 nC, 0.4% rms, 79.4/79.1 µm-rad)
# Number of cores: 5
# time =  1.7665438652038574  sec
# Tracking element 34 (StageQuasistatic2d, stage 17, s = 551.7 m, 529.9 GeV, -1.60 nC, 0.4% rms, 79.3/79.0 µm-rad)
# Tracking element 35 (InterstageBasic, stage 17, s = 586.6 m, 529.9 GeV, -1.60 nC, 0.4% rms, 79.3/79.0 µm-rad)
# Number of cores: 5
# time =  1.7007174491882324  sec
# Tracking element 36 (StageQuasistatic2d, stage 18, s = 597.6 m, 561.6 GeV, -1.60 nC, 0.4% rms, 79.2/79.0 µm-rad)
# Tracking element 37 (InterstageBasic, stage 18, s = 633.5 m, 561.6 GeV, -1.60 nC, 0.4% rms, 79.2/79.0 µm-rad)
# Number of cores: 5
# time =  1.841174840927124  sec
# Tracking element 38 (StageQuasistatic2d, stage 19, s = 644.5 m, 593.2 GeV, -1.60 nC, 0.4% rms, 79.1/78.9 µm-rad)
# Tracking element 39 (InterstageBasic, stage 19, s = 681.4 m, 593.2 GeV, -1.60 nC, 0.4% rms, 79.1/78.9 µm-rad)
# Number of cores: 5
# time =  1.6071207523345947  sec
# Tracking element 40 (StageQuasistatic2d, stage 20, s = 692.4 m, 624.9 GeV, -1.60 nC, 0.4% rms, 79.1/78.8 µm-rad)
# Tracking element 41 (InterstageBasic, stage 20, s = 730.3 m, 624.9 GeV, -1.60 nC, 0.4% rms, 79.1/78.8 µm-rad)
# Number of cores: 5
# time =  1.5685675144195557  sec
# Tracking element 42 (StageQuasistatic2d, stage 21, s = 741.3 m, 656.4 GeV, -1.60 nC, 0.5% rms, 79.0/78.8 µm-rad)
# Tracking element 43 (InterstageBasic, stage 21, s = 780.2 m, 656.4 GeV, -1.60 nC, 0.5% rms, 79.0/78.8 µm-rad)
# Number of cores: 5
# time =  1.6337409019470215  sec
# Tracking element 44 (StageQuasistatic2d, stage 22, s = 791.2 m, 688.0 GeV, -1.60 nC, 0.5% rms, 78.9/78.7 µm-rad)
# Tracking element 45 (InterstageBasic, stage 22, s = 831.0 m, 688.0 GeV, -1.60 nC, 0.5% rms, 78.9/78.7 µm-rad)
# Number of cores: 5
# time =  1.5204901695251465  sec
# Tracking element 46 (StageQuasistatic2d, stage 23, s = 842.0 m, 719.6 GeV, -1.60 nC, 0.5% rms, 78.8/78.6 µm-rad)
# Tracking element 47 (InterstageBasic, stage 23, s = 882.7 m, 719.6 GeV, -1.60 nC, 0.5% rms, 78.8/78.6 µm-rad)
# Number of cores: 5
# time =  1.446730136871338  sec
# Tracking element 48 (StageQuasistatic2d, stage 24, s = 893.7 m, 751.3 GeV, -1.60 nC, 0.5% rms, 78.8/78.5 µm-rad)
# Tracking element 49 (InterstageBasic, stage 24, s = 935.3 m, 751.3 GeV, -1.60 nC, 0.5% rms, 78.8/78.5 µm-rad)
# Number of cores: 5
# time =  1.4245316982269287  sec
# Tracking element 50 (StageQuasistatic2d, stage 25, s = 946.3 m, 782.9 GeV, -1.60 nC, 0.6% rms, 78.7/78.4 µm-rad)
# Tracking element 51 (InterstageBasic, stage 25, s = 988.7 m, 782.9 GeV, -1.60 nC, 0.6% rms, 78.7/78.4 µm-rad)
# Number of cores: 5
# time =  1.3813209533691406  sec
# Tracking element 52 (StageQuasistatic2d, stage 26, s = 999.7 m, 814.5 GeV, -1.60 nC, 0.6% rms, 78.6/78.4 µm-rad)
# Tracking element 53 (InterstageBasic, stage 26, s = 1043.1 m, 814.5 GeV, -1.60 nC, 0.6% rms, 78.6/78.4 µm-rad)
# Number of cores: 5
# time =  1.5468528270721436  sec
# Tracking element 54 (StageQuasistatic2d, stage 27, s = 1054.1 m, 846.0 GeV, -1.60 nC, 0.6% rms, 78.5/78.3 µm-rad)
# Tracking element 55 (InterstageBasic, stage 27, s = 1098.2 m, 846.0 GeV, -1.60 nC, 0.6% rms, 78.5/78.3 µm-rad)
# Number of cores: 5
# time =  1.3886349201202393  sec
# Tracking element 56 (StageQuasistatic2d, stage 28, s = 1109.2 m, 877.6 GeV, -1.60 nC, 0.7% rms, 78.4/78.2 µm-rad)
# Tracking element 57 (InterstageBasic, stage 28, s = 1154.2 m, 877.6 GeV, -1.60 nC, 0.7% rms, 78.4/78.2 µm-rad)
# Number of cores: 5
# time =  1.333451509475708  sec
# Tracking element 58 (StageQuasistatic2d, stage 29, s = 1165.2 m, 909.2 GeV, -1.60 nC, 0.7% rms, 78.3/78.1 µm-rad)
# Tracking element 59 (InterstageBasic, stage 29, s = 1210.9 m, 909.2 GeV, -1.60 nC, 0.7% rms, 78.3/78.1 µm-rad)
# Number of cores: 5
# time =  1.326493263244629  sec
# Tracking element 60 (StageQuasistatic2d, stage 30, s = 1221.9 m, 940.7 GeV, -1.60 nC, 0.7% rms, 78.2/78.0 µm-rad)
# Tracking element 61 (InterstageBasic, stage 30, s = 1268.5 m, 940.7 GeV, -1.60 nC, 0.7% rms, 78.3/78.0 µm-rad)
# Number of cores: 5
# time =  1.3513250350952148  sec
# Tracking element 62 (StageQuasistatic2d, stage 31, s = 1279.5 m, 972.1 GeV, -1.60 nC, 0.8% rms, 78.2/77.9 µm-rad)
# Tracking element 63 (InterstageBasic, stage 31, s = 1326.9 m, 972.1 GeV, -1.60 nC, 0.8% rms, 78.2/77.9 µm-rad)
# Number of cores: 5
# time =  1.2918765544891357  sec
# Tracking element 64 (StageQuasistatic2d, stage 32, s = 1337.9 m, 1003.7 GeV, -1.60 nC, 0.8% rms, 78.1/77.8 µm-rad)
# Tracking element 65 (InterstageBasic, stage 32, s = 1386.0 m, 1003.7 GeV, -1.60 nC, 0.8% rms, 78.1/77.8 µm-rad)
# Number of cores: 5
# time =  1.3013854026794434  sec
# Tracking element 66 (StageQuasistatic2d, stage 33, s = 1397.0 m, 1035.2 GeV, -1.60 nC, 0.8% rms, 78.0/77.7 µm-rad)
# Tracking element 67 (InterstageBasic, stage 33, s = 1445.8 m, 1035.2 GeV, -1.60 nC, 0.8% rms, 78.0/77.7 µm-rad)
# Number of cores: 5
# time =  1.4356052875518799  sec
# Tracking element 68 (StageQuasistatic2d, stage 34, s = 1456.8 m, 1066.7 GeV, -1.60 nC, 0.9% rms, 77.9/77.6 µm-rad)
# Tracking element 69 (InterstageBasic, stage 34, s = 1506.4 m, 1066.7 GeV, -1.60 nC, 0.9% rms, 77.9/77.6 µm-rad)
# Number of cores: 5
# time =  1.2347066402435303  sec
# Tracking element 70 (StageQuasistatic2d, stage 35, s = 1517.4 m, 1098.2 GeV, -1.60 nC, 0.9% rms, 77.8/77.5 µm-rad)
# Tracking element 71 (InterstageBasic, stage 35, s = 1567.8 m, 1098.2 GeV, -1.60 nC, 0.9% rms, 77.8/77.5 µm-rad)
# Number of cores: 5
# time =  1.2478127479553223  sec
# Tracking element 72 (StageQuasistatic2d, stage 36, s = 1578.8 m, 1129.5 GeV, -1.60 nC, 1.0% rms, 77.7/77.5 µm-rad)
# Tracking element 73 (InterstageBasic, stage 36, s = 1629.8 m, 1129.5 GeV, -1.60 nC, 1.0% rms, 77.7/77.5 µm-rad)
# Number of cores: 5
# time =  1.2385616302490234  sec
# Tracking element 74 (StageQuasistatic2d, stage 37, s = 1640.8 m, 1161.0 GeV, -1.60 nC, 1.0% rms, 77.6/77.4 µm-rad)
# Tracking element 75 (InterstageBasic, stage 37, s = 1692.6 m, 1161.0 GeV, -1.60 nC, 1.0% rms, 77.6/77.4 µm-rad)
# Number of cores: 5
# time =  1.205829381942749  sec
# Tracking element 76 (StageQuasistatic2d, stage 38, s = 1703.6 m, 1192.3 GeV, -1.60 nC, 1.0% rms, 77.5/77.3 µm-rad)
# Tracking element 77 (InterstageBasic, stage 38, s = 1756.1 m, 1192.3 GeV, -1.60 nC, 1.0% rms, 77.5/77.3 µm-rad)
# Number of cores: 5
# time =  1.1888465881347656  sec
# Tracking element 78 (StageQuasistatic2d, stage 39, s = 1767.1 m, 1223.6 GeV, -1.60 nC, 1.1% rms, 77.4/77.2 µm-rad)
# Tracking element 79 (InterstageBasic, stage 39, s = 1820.2 m, 1223.6 GeV, -1.60 nC, 1.1% rms, 77.4/77.2 µm-rad)
# Number of cores: 5
# time =  1.1755437850952148  sec
# Tracking element 80 (StageQuasistatic2d, stage 40, s = 1831.2 m, 1255.0 GeV, -1.60 nC, 1.1% rms, 77.3/77.1 µm-rad)
# Tracking element 81 (InterstageBasic, stage 40, s = 1885.1 m, 1255.0 GeV, -1.60 nC, 1.1% rms, 77.3/77.1 µm-rad)
# Number of cores: 5
# time =  1.217264175415039  sec
# Tracking element 82 (StageQuasistatic2d, stage 41, s = 1896.1 m, 1286.5 GeV, -1.60 nC, 1.1% rms, 77.2/77.0 µm-rad)
# Tracking element 83 (InterstageBasic, stage 41, s = 1950.6 m, 1286.5 GeV, -1.60 nC, 1.1% rms, 77.2/77.0 µm-rad)
# Number of cores: 5
# time =  1.1723334789276123  sec
# Tracking element 84 (StageQuasistatic2d, stage 42, s = 1961.6 m, 1318.0 GeV, -1.60 nC, 1.2% rms, 77.1/76.9 µm-rad)
# Tracking element 85 (InterstageBasic, stage 42, s = 2016.8 m, 1318.0 GeV, -1.60 nC, 1.2% rms, 77.1/76.9 µm-rad)
# Number of cores: 5
# time =  1.1946330070495605  sec
# Tracking element 86 (StageQuasistatic2d, stage 43, s = 2027.8 m, 1349.4 GeV, -1.60 nC, 1.2% rms, 77.0/76.8 µm-rad)
# Tracking element 87 (InterstageBasic, stage 43, s = 2083.6 m, 1349.4 GeV, -1.60 nC, 1.2% rms, 77.0/76.8 µm-rad)
# Number of cores: 5
# time =  1.127007246017456  sec
# Tracking element 88 (StageQuasistatic2d, stage 44, s = 2094.6 m, 1380.7 GeV, -1.60 nC, 1.2% rms, 76.9/76.7 µm-rad)
# Tracking element 89 (InterstageBasic, stage 44, s = 2151.1 m, 1380.7 GeV, -1.60 nC, 1.2% rms, 76.9/76.7 µm-rad)
# Number of cores: 5
# time =  1.1343281269073486  sec
# Tracking element 90 (StageQuasistatic2d, stage 45, s = 2162.1 m, 1412.0 GeV, -1.60 nC, 1.3% rms, 76.8/76.6 µm-rad)
# Tracking element 91 (InterstageBasic, stage 45, s = 2219.3 m, 1412.0 GeV, -1.60 nC, 1.3% rms, 76.8/76.6 µm-rad)
# Number of cores: 5
# time =  1.1312341690063477  sec
# Tracking element 92 (StageQuasistatic2d, stage 46, s = 2230.3 m, 1443.4 GeV, -1.60 nC, 1.3% rms, 76.7/76.5 µm-rad)
# Tracking element 93 (InterstageBasic, stage 46, s = 2288.1 m, 1443.4 GeV, -1.60 nC, 1.3% rms, 76.7/76.5 µm-rad)
# Number of cores: 5
# time =  1.1059973239898682  sec
# Tracking element 94 (StageQuasistatic2d, stage 47, s = 2299.1 m, 1474.8 GeV, -1.60 nC, 1.4% rms, 76.6/76.4 µm-rad)
# Tracking element 95 (InterstageBasic, stage 47, s = 2357.5 m, 1474.8 GeV, -1.60 nC, 1.4% rms, 76.6/76.4 µm-rad)
# Number of cores: 5
# time =  1.1131811141967773  sec
# Tracking element 96 (StageQuasistatic2d, stage 48, s = 2368.5 m, 1506.2 GeV, -1.60 nC, 1.4% rms, 76.5/76.3 µm-rad)
# 4.772137415409088  min

# %% [markdown]
# ### Plot the wakefield

# %%
# plot the first-stage wakefield
linac.stages[0].plot_wakefield()

# %%
# plot the last-stage wakefield
linac.stages[-1].plot_wakefield()

# %%
wake0 = linac.stages[0].plot_wake()
wake_final = linac.stages[-1].plot_wake()
if linac.num_stages < 17 and stage.enable_radiation_reaction == False:
    wake0.savefig(f'Plots/Round_Beam/wake0_Round_Beam_RR_{stage.enable_radiation_reaction}_stages_{linac.num_stages}', bbox_inches='tight')
    wake_final.savefig(f'Plots/Round_Beam/wake_final_Round_Beam_RR_{stage.enable_radiation_reaction}_stages_{linac.num_stages}', bbox_inches='tight')
else:
    wake_final.savefig(f'Plots/Round_Beam/wake_final_Round_Beam_RR_{stage.enable_radiation_reaction}_stages_{linac.num_stages}', bbox_inches='tight')

# %%
#fig = linac.stages[0].plot_evolution()
fig_last = linac.stages[-1].plot_evolution()
# Out:
# No evolution calculated

# %% [markdown]
# ### Plot beam evolution and survey

# %%
# plot linac survey
linac.plot_survey()

# plot beam evolution
beam_evolution = linac.plot_evolution(use_stage_nums=False)
beam_evolution.savefig(f"Plots/Round_Beam/beam_evolution_Round_Beam_RR_{stage.enable_radiation_reaction}\
_stages_{linac.num_stages}.png", bbox_inches = 'tight')
#linac[0].plot_waterfalls()

# %%
gif = linac.animate_lps()

# %% [markdown]
# ![](run_data/linac_example/plots/lps_shot0.gif)

# %%
stage_num = 15
shot_num = 0
stage_tracked = linac[shot_num].stages[stage_num]  # Get a specific acceleration stage in a linac. Zero indexing.
beam_out = linac[shot_num].get_beam(stage_num*2+1)  # Get the corresponding beam after the acceleration stage. Zero indexing.

# %% [raw]
# #plt.hist(beam.xs()**2, bins = 100)
# x_2 = np.linspace(0,2e-9,100)
# gamma = source.energy*SI.e/SI.m_e/SI.c**2
# kp = pp.k_p(stage.plasma_density)
# #plt.plot(x_2, np.exp(-x_2/(np.sqrt(2/gamma)*source.emit_nx/kp)))
# #plt.yscale('log')
# sig_x = np.sqrt(np.sqrt(2/gamma)*source.emit_nx/kp)*1e6
# fig, ax = plt.subplots(tight_layout = True)
#
# A = np.sqrt(beam.xs()**2 + beam.xps()**2*(source.beta_x)**2)*1e6
# A_lin = np.linspace(0,1.8e-5, 100)*1e6
# A_prob = A_lin/sig_x**2*np.exp(-0.5*A_lin**2/sig_x**2)
# ax.plot(A_lin,A_prob, label = 'Analytical PDF')
# ax.hist(A, bins = 100, density = True, stacked=True, label = 'Actual distribution of beam')
# ax.grid()
# ax.set_xlabel('Amplitude [$\mu m$]')
# ax.set_ylabel('Probability Density')
# ax.set_title('Probability Distribution of Particle Amplitudes')
# ax.legend()
# plt.show()
# #fig.savefig('PDF_amplitudes')
# #print('sig_x² = ', np.sqrt(2/gamma)*source.emit_nx/kp)
# #print(np.sqrt(np.mean(A**2)))
# #print((np.mean(A**2))/sig_x**2)
# #print(np.trapz(A_lin/sig_x**2*np.exp(-0.5*A_lin**2/sig_x**2),A_lin))

# %%
Final_energies = [linac.get_beam(-1, shot = i).energy()/1e9 for i in range(shots)]
Final_spread = [linac.get_beam(-1, shot = i).rel_energy_spread() for i in range(shots)]
energy_standard_error = np.std(Final_energies)
mean_energy = np.mean(Final_energies)
print('RMS energy spread is ', energy_standard_error, 'Mean final energy is ', mean_energy)

gamma = source.energy*SI.e/SI.m_e/SI.c**2
kp = pp.k_p(stage.plasma_density)
k_beta = kp/np.sqrt(2*gamma)
sig_x2 = (np.sqrt(2/gamma)*source.emit_nx/kp)
sig_y2 = (np.sqrt(2/gamma)*source.emit_ny/kp)

Expected_energy_loss = SI.e**2/6/np.pi/SI.epsilon_0 * (gamma*k_beta)**4*(sig_x2+sig_y2)*stage.length
Expected_energy_spread = SI.e**2/6/np.pi/SI.epsilon_0 * (gamma*k_beta)**4*\
np.sqrt((sig_x2**2+sig_y2**2))*stage.length/(source.energy*SI.e)

print('expected energy loss is ', Expected_energy_loss/SI.e/1e9)
print('expected energy spread is ', Expected_energy_spread)
print('actual energy spread is ', np.mean(Final_spread), \
      'standard error in energy spread is ', np.std(Final_spread))
