# %%
import sys
sys.path.append('../../ABEL/')
from abel import *

# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import time
import scipy.constants as SI 
import abel.utilities.plasma_physics as pp
import matplotlib.pyplot as plt
from abel.utilities.relativity import energy2gamma

# %%
# define driver
driver = SourceBasic()
driver.charge = -2.7e10 * SI.e # [C]
driver.energy = 31.25e9 # [eV]
driver.rel_energy_spread = 0.01
driver.bunch_length = 50e-6 # [m]
driver.z_offset = 580e-6 # [m]
driver.emit_nx, driver.emit_ny = 80e-6, 80e-6 # [m rad]
driver.beta_x, driver.beta_y = 5, 5 #30e-3, 30e-3 # [m]
driver.num_particles = 100000
driver.jitter.x = 0 # [m] 2e-6
driver.jitter.y = 0 # [m] 100e-9
driver.jitter.t = 0 # 10e-15 # [m]
driver.symmetrize = True
#drive_beam = driver.track()  # Convert a Source object to a Beam object.  ######


# define stage
stage = StageQuasistatic2d()
#stage = StagePrtclTransWakeInstability()                      #######
#stage.drive_beam = drive_beam                                 #######
stage.driver_source = driver
stage.length = 11 # [m]
stage.nom_energy_gain = 31.9e9 # [eV]
stage.plasma_density = 2e21 # [m^-3]
stage.ramp_beta_mag = 5
stage.enable_radiation_reaction = True
stage.save_evolution = True
if stage.enable_radiation_reaction == False:
    stage.save_evolution = False

# define first stage (half length)
first_stage = StageQuasistatic2d()
#first_stage = StagePrtclTransWakeInstability()                      #######
#first_stage.drive_beam = drive_beam                                 #######
first_stage.driver_source = driver
first_stage.nom_energy_gain = stage.nom_energy_gain/2
first_stage.length = stage.length/2
first_stage.plasma_density = stage.plasma_density
first_stage.ramp_beta_mag = stage.ramp_beta_mag
first_stage.enable_radiation_reaction = stage.enable_radiation_reaction
first_stage.save_evolution = stage.save_evolution

# define beam
source = SourceBasic()
source.charge = -1e10 * SI.e # [C]
source.energy = 7500e9 # [eV]
#source.rel_energy_spread = 0.1
source.rel_energy_spread = 0.01
source.bunch_length = 10e-6 # [m]
source.z_offset = 0e-6 # [m]
source.emit_nx, source.emit_ny = 80e-6, 80e-6 # [m rad]
source.beta_x = stage.matched_beta_function(source.energy)
source.beta_y = source.beta_x
source.num_particles = 50000
source.jitter.t = driver.jitter.t
source.symmetrize = True
#beam = source.track()

"""
main_gamma = energy2gamma(source.energy)
main_sigma_x = np.sqrt(source.emit_nx/main_gamma*source.beta_x)  # [m]
main_sigma_y = np.sqrt(source.emit_ny/main_gamma*source.beta_y)  # [m]
source.x_offset = main_sigma_x*0.1  # [m]
source.y_offset = main_sigma_y*0.1  # [m]
"""
# define interstage
interstage = InterstageBasic()
#interstage = InterstageElegant()
interstage.beta0 = lambda E: stage.matched_beta_function(E)
interstage.dipole_length = lambda E: 1 * np.sqrt(E/10e9) # [m(eV)]
interstage.dipole_field = 1.  # [T]
#interstage.dipole_field = lambda E: np.min([1.0, 100e9/E]) # [T]

# beam delivery system
bds = BeamDeliverySystemBasic()
bds.beta_x, bds.beta_y = 8e-3, 0.4e-3 # [m]
bds.bunch_length = 0.75 * bds.beta_y

# define linac
linac = Linac()
linac.source = source
linac.stage = stage
#linac.first_stage = first_stage
linac.interstage = interstage
linac.num_stages = 1
shots = 1
num_jitter_values = 8
jitter_values = np.logspace(-7,-5.6,num_jitter_values)
print(jitter_values)
# Out:
# [1.00000000e-07 1.58489319e-07 2.51188643e-07 3.98107171e-07
#  6.30957344e-07 1.00000000e-06 1.58489319e-06 2.51188643e-06]

# %%
# scan the driver timing jitter
linac.scan(f'scan_jitter_with_RR_{stage.enable_radiation_reaction}', 
           lambda obj, val: setattr(obj.stage.driver_source.jitter, 'x', val) or setattr(obj.stage.driver_source.jitter, 'y', val) or obj, 
           jitter_values,
           label='Driver jitter [$\mu m$]',
           scale=1e-6,
           num_shots_per_step=100, 
           parallel=False,
           overwrite=False);
# Out:
# >> SHOT 1 already exists and will not be overwritten.
# >> SHOT 2 already exists and will not be overwritten.
# >> SHOT 3 already exists and will not be overwritten.
# >> SHOT 4 already exists and will not be overwritten.
# >> SHOT 5 already exists and will not be overwritten.
# >> SHOT 6 already exists and will not be overwritten.
# >> SHOT 7 already exists and will not be overwritten.
# >> SHOT 8 already exists and will not be overwritten.
# >> SHOT 9 already exists and will not be overwritten.
# >> SHOT 10 already exists and will not be overwritten.
# >> SHOT 11 already exists and will not be overwritten.
# >> SHOT 12 already exists and will not be overwritten.
# >> SHOT 13 already exists and will not be overwritten.
# >> SHOT 14 already exists and will not be overwritten.
# >> SHOT 15 already exists and will not be overwritten.
# >> SHOT 16 already exists and will not be overwritten.
# >> SHOT 17 already exists and will not be overwritten.
# >> SHOT 18 already exists and will not be overwritten.
# >> SHOT 19 already exists and will not be overwritten.
# >> SHOT 20 already exists and will not be overwritten.
# >> SHOT 21 already exists and will not be overwritten.
# >> SHOT 22 already exists and will not be overwritten.
# >> SHOT 23 already exists and will not be overwritten.
# >> SHOT 24 already exists and will not be overwritten.
# >> SHOT 25 already exists and will not be overwritten.
# >> SHOT 26 already exists and will not be overwritten.
# >> SHOT 27 already exists and will not be overwritten.
# >> SHOT 28 already exists and will not be overwritten.
# >> SHOT 29 already exists and will not be overwritten.
# >> SHOT 30 already exists and will not be overwritten.
# >> SHOT 31 already exists and will not be overwritten.
# >> SHOT 32 already exists and will not be overwritten.
# >> SHOT 33 already exists and will not be overwritten.
# >> SHOT 34 already exists and will not be overwritten.
# >> SHOT 35 already exists and will not be overwritten.
# >> SHOT 36 already exists and will not be overwritten.
# >> SHOT 37 already exists and will not be overwritten.
# >> SHOT 38 already exists and will not be overwritten.
# >> SHOT 39 already exists and will not be overwritten.
# >> SHOT 40 already exists and will not be overwritten.
# >> SHOT 41 already exists and will not be overwritten.
# >> SHOT 42 already exists and will not be overwritten.
# >> SHOT 43 already exists and will not be overwritten.
# >> SHOT 44 already exists and will not be overwritten.
# >> SHOT 45 already exists and will not be overwritten.
# >> SHOT 46 already exists and will not be overwritten.
# >> SHOT 47 already exists and will not be overwritten.
# >> SHOT 48 already exists and will not be overwritten.
# >> SHOT 49 already exists and will not be overwritten.
# >> SHOT 50 already exists and will not be overwritten.
# >> SHOT 51 already exists and will not be overwritten.
# >> SHOT 52 already exists and will not be overwritten.
# >> SHOT 53 already exists and will not be overwritten.
# >> SHOT 54 already exists and will not be overwritten.
# >> SHOT 55 already exists and will not be overwritten.
# >> SHOT 56 already exists and will not be overwritten.
# >> SHOT 57 already exists and will not be overwritten.
# >> SHOT 58 already exists and will not be overwritten.
# >> SHOT 59 already exists and will not be overwritten.
# >> SHOT 60 already exists and will not be overwritten.
# >> SHOT 61 already exists and will not be overwritten.
# >> SHOT 62 already exists and will not be overwritten.
# >> SHOT 63 already exists and will not be overwritten.
# >> SHOT 64 already exists and will not be overwritten.
# >> SHOT 65 already exists and will not be overwritten.
# >> SHOT 66 already exists and will not be overwritten.
# >> SHOT 67 already exists and will not be overwritten.
# >> SHOT 68 already exists and will not be overwritten.
# >> SHOT 69 already exists and will not be overwritten.
# >> SHOT 70 already exists and will not be overwritten.
# >> SHOT 71 already exists and will not be overwritten.
# >> SHOT 72 already exists and will not be overwritten.
# >> SHOT 73 already exists and will not be overwritten.
# >> SHOT 74 already exists and will not be overwritten.
# >> SHOT 75 already exists and will not be overwritten.
# >> SHOT 76 already exists and will not be overwritten.
# >> SHOT 77 already exists and will not be overwritten.
# >> SHOT 78 already exists and will not be overwritten.
# >> SHOT 79 already exists and will not be overwritten.
# >> SHOT 80 already exists and will not be overwritten.
# >> SHOT 81 already exists and will not be overwritten.
# >> SHOT 82 already exists and will not be overwritten.
# >> SHOT 83 already exists and will not be overwritten.
# >> SHOT 84 already exists and will not be overwritten.
# >> SHOT 85 already exists and will not be overwritten.
# >> SHOT 86 already exists and will not be overwritten.
# >> SHOT 87 already exists and will not be overwritten.
# >> SHOT 88 already exists and will not be overwritten.
# >> SHOT 89 already exists and will not be overwritten.
# >> SHOT 90 already exists and will not be overwritten.
# >> SHOT 91 already exists and will not be overwritten.
# >> SHOT 92 already exists and will not be overwritten.
# >> SHOT 93 already exists and will not be overwritten.
# >> SHOT 94 already exists and will not be overwritten.
# >> SHOT 95 already exists and will not be overwritten.
# >> SHOT 96 already exists and will not be overwritten.
# >> SHOT 97 already exists and will not be overwritten.
# >> SHOT 98 already exists and will not be overwritten.
# >> SHOT 99 already exists and will not be overwritten.
# >> SHOT 100 already exists and will not be overwritten.
# >> SHOT 101 already exists and will not be overwritten.
# >> SHOT 102 already exists and will not be overwritten.
# >> SHOT 103 already exists and will not be overwritten.
# >> SHOT 104 already exists and will not be overwritten.
# >> SHOT 105 already exists and will not be overwritten.
# >> SHOT 106 already exists and will not be overwritten.
# >> SHOT 107 already exists and will not be overwritten.
# >> SHOT 108 already exists and will not be overwritten.
# >> SHOT 109 already exists and will not be overwritten.
# >> SHOT 110 already exists and will not be overwritten.
# >> SHOT 111 already exists and will not be overwritten.
# >> SHOT 112 already exists and will not be overwritten.
# >> SHOT 113 already exists and will not be overwritten.
# >> SHOT 114 already exists and will not be overwritten.
# >> SHOT 115 already exists and will not be overwritten.
# >> SHOT 116 already exists and will not be overwritten.
# >> SHOT 117 already exists and will not be overwritten.
# >> SHOT 118 already exists and will not be overwritten.
# >> SHOT 119 already exists and will not be overwritten.
# >> SHOT 120 already exists and will not be overwritten.
# >> SHOT 121 already exists and will not be overwritten.
# >> SHOT 122 already exists and will not be overwritten.
# >> SHOT 123 already exists and will not be overwritten.
# >> SHOT 124 already exists and will not be overwritten.
# >> SHOT 125 already exists and will not be overwritten.
# >> SHOT 126 already exists and will not be overwritten.
# >> SHOT 127 already exists and will not be overwritten.
# >> SHOT 128 already exists and will not be overwritten.
# >> SHOT 129 already exists and will not be overwritten.
# >> SHOT 130 already exists and will not be overwritten.
# >> SHOT 131 already exists and will not be overwritten.
# >> SHOT 132 already exists and will not be overwritten.
# >> SHOT 133 already exists and will not be overwritten.
# >> SHOT 134 already exists and will not be overwritten.
# >> SHOT 135 already exists and will not be overwritten.
# >> SHOT 136 already exists and will not be overwritten.
# >> SHOT 137 already exists and will not be overwritten.
# >> SHOT 138 already exists and will not be overwritten.
# >> SHOT 139 already exists and will not be overwritten.
# >> SHOT 140 already exists and will not be overwritten.
# >> SHOT 141 already exists and will not be overwritten.
# >> SHOT 142 already exists and will not be overwritten.
# >> SHOT 143 already exists and will not be overwritten.
# >> SHOT 144 already exists and will not be overwritten.
# >> SHOT 145 already exists and will not be overwritten.
# >> SHOT 146 already exists and will not be overwritten.
# >> SHOT 147 already exists and will not be overwritten.
# >> SHOT 148 already exists and will not be overwritten.
# >> SHOT 149 already exists and will not be overwritten.
# >> SHOT 150 already exists and will not be overwritten.
# >> SHOT 151 already exists and will not be overwritten.
# >> SHOT 152 already exists and will not be overwritten.
# >> SHOT 153 already exists and will not be overwritten.
# >> SHOT 154 already exists and will not be overwritten.
# >> SHOT 155 already exists and will not be overwritten.
# >> SHOT 156 already exists and will not be overwritten.
# >> SHOT 157 already exists and will not be overwritten.
# >> SHOT 158 already exists and will not be overwritten.
# >> SHOT 159 already exists and will not be overwritten.
# >> SHOT 160 already exists and will not be overwritten.
# >> SHOT 161 already exists and will not be overwritten.
# >> SHOT 162 already exists and will not be overwritten.
# >> SHOT 163 already exists and will not be overwritten.
# >> SHOT 164 already exists and will not be overwritten.
# >> SHOT 165 already exists and will not be overwritten.
# >> SHOT 166 already exists and will not be overwritten.
# >> SHOT 167 already exists and will not be overwritten.
# >> SHOT 168 already exists and will not be overwritten.
# >> SHOT 169 already exists and will not be overwritten.
# >> SHOT 170 already exists and will not be overwritten.
# >> SHOT 171 already exists and will not be overwritten.
# >> SHOT 172 already exists and will not be overwritten.
# >> SHOT 173 already exists and will not be overwritten.
# >> SHOT 174 already exists and will not be overwritten.
# >> SHOT 175 already exists and will not be overwritten.
# >> SHOT 176 already exists and will not be overwritten.
# >> SHOT 177 already exists and will not be overwritten.
# >> SHOT 178 already exists and will not be overwritten.
# >> SHOT 179 already exists and will not be overwritten.
# >> SHOT 180 already exists and will not be overwritten.
# >> SHOT 181 already exists and will not be overwritten.
# >> SHOT 182 already exists and will not be overwritten.
# >> SHOT 183 already exists and will not be overwritten.
# >> SHOT 184 already exists and will not be overwritten.
# >> SHOT 185 already exists and will not be overwritten.
# >> SHOT 186 already exists and will not be overwritten.
# >> SHOT 187 already exists and will not be overwritten.
# >> SHOT 188 already exists and will not be overwritten.
# >> SHOT 189 already exists and will not be overwritten.
# >> SHOT 190 already exists and will not be overwritten.
# >> SHOT 191 already exists and will not be overwritten.
# >> SHOT 192 already exists and will not be overwritten.
# >> SHOT 193 already exists and will not be overwritten.
# >> SHOT 194 already exists and will not be overwritten.
# >> SHOT 195 already exists and will not be overwritten.
# >> SHOT 196 already exists and will not be overwritten.
# >> SHOT 197 already exists and will not be overwritten.
# >> SHOT 198 already exists and will not be overwritten.
# >> SHOT 199 already exists and will not be overwritten.
# >> SHOT 200 already exists and will not be overwritten.
# >> SHOT 201 already exists and will not be overwritten.
# >> SHOT 202 already exists and will not be overwritten.
# >> SHOT 203 already exists and will not be overwritten.
# >> SHOT 204 already exists and will not be overwritten.
# >> SHOT 205 already exists and will not be overwritten.
# >> SHOT 206 already exists and will not be overwritten.
# >> SHOT 207 already exists and will not be overwritten.
# >> SHOT 208 already exists and will not be overwritten.
# >> SHOT 209 already exists and will not be overwritten.
# >> SHOT 210 already exists and will not be overwritten.
# >> SHOT 211 already exists and will not be overwritten.
# >> SHOT 212 already exists and will not be overwritten.
# >> SHOT 213 already exists and will not be overwritten.
# >> SHOT 214 already exists and will not be overwritten.
# >> SHOT 215 already exists and will not be overwritten.
# >> SHOT 216 already exists and will not be overwritten.
# >> SHOT 217 already exists and will not be overwritten.
# >> SHOT 218 already exists and will not be overwritten.
# >> SHOT 219 already exists and will not be overwritten.
# >> SHOT 220 already exists and will not be overwritten.
# >> SHOT 221 already exists and will not be overwritten.
# >> SHOT 222 already exists and will not be overwritten.
# >> SHOT 223 already exists and will not be overwritten.
# >> SHOT 224 already exists and will not be overwritten.
# >> SHOT 225 already exists and will not be overwritten.
# >> SHOT 226 already exists and will not be overwritten.
# >> SHOT 227 already exists and will not be overwritten.
# >> SHOT 228 already exists and will not be overwritten.
# >> SHOT 229 already exists and will not be overwritten.
# >> SHOT 230 already exists and will not be overwritten.
# >> SHOT 231 already exists and will not be overwritten.
# >> SHOT 232 already exists and will not be overwritten.
# >> SHOT 233 already exists and will not be overwritten.
# >> SHOT 234 already exists and will not be overwritten.
# >> SHOT 235 already exists and will not be overwritten.
# >> SHOT 236 already exists and will not be overwritten.
# >> SHOT 237 already exists and will not be overwritten.
# >> SHOT 238 already exists and will not be overwritten.
# >> SHOT 239 already exists and will not be overwritten.
# >> SHOT 240 already exists and will not be overwritten.
# >> SHOT 241 already exists and will not be overwritten.
# >> SHOT 242 already exists and will not be overwritten.
# >> SHOT 243 already exists and will not be overwritten.
# >> SHOT 244 already exists and will not be overwritten.
# >> SHOT 245 already exists and will not be overwritten.
# >> SHOT 246 already exists and will not be overwritten.
# >> SHOT 247 already exists and will not be overwritten.
# >> SHOT 248 already exists and will not be overwritten.
# >> SHOT 249 already exists and will not be overwritten.
# >> SHOT 250 already exists and will not be overwritten.
# >> SHOT 251 already exists and will not be overwritten.
# >> SHOT 252 already exists and will not be overwritten.
# >> SHOT 253 already exists and will not be overwritten.
# >> SHOT 254 already exists and will not be overwritten.
# >> SHOT 255 already exists and will not be overwritten.
# >> SHOT 256 already exists and will not be overwritten.
# >> SHOT 257 already exists and will not be overwritten.
# >> SHOT 258 already exists and will not be overwritten.
# >> SHOT 259 already exists and will not be overwritten.
# >> SHOT 260 already exists and will not be overwritten.
# >> SHOT 261 already exists and will not be overwritten.
# >> SHOT 262 already exists and will not be overwritten.
# >> SHOT 263 already exists and will not be overwritten.
# >> SHOT 264 already exists and will not be overwritten.
# >> SHOT 265 already exists and will not be overwritten.
# >> SHOT 266 already exists and will not be overwritten.
# >> SHOT 267 already exists and will not be overwritten.
# >> SHOT 268 already exists and will not be overwritten.
# >> SHOT 269 already exists and will not be overwritten.
# >> SHOT 270 already exists and will not be overwritten.
# >> SHOT 271 already exists and will not be overwritten.
# >> SHOT 272 already exists and will not be overwritten.
# >> SHOT 273 already exists and will not be overwritten.
# >> SHOT 274 already exists and will not be overwritten.
# >> SHOT 275 already exists and will not be overwritten.
# >> SHOT 276 already exists and will not be overwritten.
# >> SHOT 277 already exists and will not be overwritten.
# >> SHOT 278 already exists and will not be overwritten.
# >> SHOT 279 already exists and will not be overwritten.
# >> SHOT 280 already exists and will not be overwritten.
# >> SHOT 281 already exists and will not be overwritten.
# >> SHOT 282 already exists and will not be overwritten.
# >> SHOT 283 already exists and will not be overwritten.
# >> SHOT 284 already exists and will not be overwritten.
# >> SHOT 285 already exists and will not be overwritten.
# >> SHOT 286 already exists and will not be overwritten.
# >> SHOT 287 already exists and will not be overwritten.
# >> SHOT 288 already exists and will not be overwritten.
# >> SHOT 289 already exists and will not be overwritten.
# >> SHOT 290 already exists and will not be overwritten.
# >> SHOT 291 already exists and will not be overwritten.
# >> SHOT 292 already exists and will not be overwritten.
# >> SHOT 293 already exists and will not be overwritten.
# >> SHOT 294 already exists and will not be overwritten.
# >> SHOT 295 already exists and will not be overwritten.
# >> SHOT 296 already exists and will not be overwritten.
# >> SHOT 297 already exists and will not be overwritten.
# >> SHOT 298 already exists and will not be overwritten.
# >> SHOT 299 already exists and will not be overwritten.
# >> SHOT 300 already exists and will not be overwritten.
# >> SHOT 301 already exists and will not be overwritten.
# >> SHOT 302 already exists and will not be overwritten.
# >> SHOT 303 already exists and will not be overwritten.
# >> SHOT 304 already exists and will not be overwritten.
# >> SHOT 305 already exists and will not be overwritten.
# >> SHOT 306 already exists and will not be overwritten.
# >> SHOT 307 already exists and will not be overwritten.
# >> SHOT 308 already exists and will not be overwritten.
# >> SHOT 309 already exists and will not be overwritten.
# >> SHOT 310 already exists and will not be overwritten.
# >> SHOT 311 already exists and will not be overwritten.
# >> SHOT 312 already exists and will not be overwritten.
# >> SHOT 313 already exists and will not be overwritten.
# >> SHOT 314 already exists and will not be overwritten.
# >> SHOT 315 already exists and will not be overwritten.
# >> SHOT 316 already exists and will not be overwritten.
# >> SHOT 317 already exists and will not be overwritten.
# >> SHOT 318 already exists and will not be overwritten.
# >> SHOT 319 already exists and will not be overwritten.
# >> SHOT 320 already exists and will not be overwritten.
# >> SHOT 321 already exists and will not be overwritten.
# >> SHOT 322 already exists and will not be overwritten.
# >> SHOT 323 already exists and will not be overwritten.
# >> SHOT 324 already exists and will not be overwritten.
# >> SHOT 325 already exists and will not be overwritten.
# >> SHOT 326 already exists and will not be overwritten.
# >> SHOT 327 already exists and will not be overwritten.
# >> SHOT 328 already exists and will not be overwritten.
# >> SHOT 329 already exists and will not be overwritten.
# >> SHOT 330 already exists and will not be overwritten.
# >> SHOT 331 already exists and will not be overwritten.
# >> SHOT 332 already exists and will not be overwritten.
# >> SHOT 333 already exists and will not be overwritten.
# >> SHOT 334 already exists and will not be overwritten.
# >> SHOT 335 already exists and will not be overwritten.
# >> SHOT 336 already exists and will not be overwritten.
# >> SHOT 337 already exists and will not be overwritten.
# >> SHOT 338 already exists and will not be overwritten.
# >> SHOT 339 already exists and will not be overwritten.
# >> SHOT 340 already exists and will not be overwritten.
# >> SHOT 341 already exists and will not be overwritten.
# >> SHOT 342 already exists and will not be overwritten.
# >> SHOT 343 already exists and will not be overwritten.
# >> SHOT 344 already exists and will not be overwritten.
# >> SHOT 345 already exists and will not be overwritten.
# >> SHOT 346 already exists and will not be overwritten.
# >> SHOT 347 already exists and will not be overwritten.
# >> SHOT 348 already exists and will not be overwritten.
# >> SHOT 349 already exists and will not be overwritten.
# >> SHOT 350 already exists and will not be overwritten.
# >> SHOT 351 already exists and will not be overwritten.
# >> SHOT 352 already exists and will not be overwritten.
# >> SHOT 353 already exists and will not be overwritten.
# >> SHOT 354 already exists and will not be overwritten.
# >> SHOT 355 already exists and will not be overwritten.
# >> SHOT 356 already exists and will not be overwritten.
# >> SHOT 357 already exists and will not be overwritten.
# >> SHOT 358 already exists and will not be overwritten.
# >> SHOT 359 already exists and will not be overwritten.
# >> SHOT 360 already exists and will not be overwritten.
# >> SHOT 361 already exists and will not be overwritten.
# >> SHOT 362 already exists and will not be overwritten.
# >> SHOT 363 already exists and will not be overwritten.
# >> SHOT 364 already exists and will not be overwritten.
# >> SHOT 365 already exists and will not be overwritten.
# >> SHOT 366 already exists and will not be overwritten.
# >> SHOT 367 already exists and will not be overwritten.
# >> SHOT 368 already exists and will not be overwritten.
# >> SHOT 369 already exists and will not be overwritten.
# >> SHOT 370 already exists and will not be overwritten.
# >> SHOT 371 already exists and will not be overwritten.
# >> SHOT 372 already exists and will not be overwritten.
# >> SHOT 373 already exists and will not be overwritten.
# >> SHOT 374 already exists and will not be overwritten.
# >> SHOT 375 already exists and will not be overwritten.
# >> SHOT 376 already exists and will not be overwritten.
# >> SHOT 377 already exists and will not be overwritten.
# >> SHOT 378 already exists and will not be overwritten.
# >> SHOT 379 already exists and will not be overwritten.
# >> SHOT 380 already exists and will not be overwritten.
# >> SHOT 381 already exists and will not be overwritten.
# >> SHOT 382 already exists and will not be overwritten.
# >> SHOT 383 already exists and will not be overwritten.
# >> SHOT 384 already exists and will not be overwritten.
# >> SHOT 385 already exists and will not be overwritten.
# >> SHOT 386 already exists and will not be overwritten.
# >> SHOT 387 already exists and will not be overwritten.
# >> SHOT 388 already exists and will not be overwritten.
# >> SHOT 389 already exists and will not be overwritten.
# >> SHOT 390 already exists and will not be overwritten.
# >> SHOT 391 already exists and will not be overwritten.
# >> SHOT 392 already exists and will not be overwritten.
# >> SHOT 393 already exists and will not be overwritten.
# >> SHOT 394 already exists and will not be overwritten.
# >> SHOT 395 already exists and will not be overwritten.
# >> SHOT 396 already exists and will not be overwritten.
# >> SHOT 397 already exists and will not be overwritten.
# >> SHOT 398 already exists and will not be overwritten.
# >> SHOT 399 already exists and will not be overwritten.
# >> SHOT 400 already exists and will not be overwritten.

# %%
linac.plot_beam_function(Beam.rel_energy_spread, label='Rel energy spread (%)', scale=1e-2, xscale='log')
linac.plot_beam_function(Beam.norm_emittance_x, label='norm emittance x (mm mrad)', scale=1e-6, xscale='log')
linac.plot_beam_function(Beam.norm_emittance_y, label='norm emittance y (mm mrad)', scale=1e-6, xscale='log')
linac.plot_beam_function(lambda obj:obj.energy() - source.energy, label='Energy Gain (GeV)', scale=1e9, xscale='log')

# %%
list_of_E_ararys = [ [] for _ in range(num_jitter_values)]
print(list_of_E_ararys)
for j in range(num_jitter_values):
    Es = [linac[j,i].get_beam(-1).energy()/1e9 for i in range(linac.num_shots_per_step)]
    list_of_E_ararys[j] = Es
# Out:
# [[], [], [], [], [], [], [], []]

# %%
def rho(sig_jitter, El):
    gamma = energy2gamma(source.energy)
    kp = pp.k_p(stage.plasma_density)
    k_beta = kp/np.sqrt(2*gamma)
    sig_x_sq = source.emit_nx/k_beta/gamma
    sig_y_sq = source.emit_ny/k_beta/gamma
    
    energy_loss_beam = SI.e**2*stage.length/6/np.pi/SI.epsilon_0*(gamma*k_beta)**4*(sig_x_sq+sig_y_sq)  /SI.e/1e9
    
    sig_Ej = np.sqrt(SI.e**2*SI.c/12/np.pi/SI.epsilon_0*(gamma*k_beta)**4)*sig_jitter*stage.length/SI.c /SI.e/1e9
    
    energy_loss_jitter_dist = np.sqrt(2/np.pi)/sig_Ej * np.exp(-1/2 * \
         ((El-(source.energy/1e9 + stage.nom_energy_gain/1e9 - energy_loss_beam))/sig_Ej)**2)
    return energy_loss_jitter_dist

# %%
plt.subplots_adjust(hspace=0.4)
fig, axs = plt.subplots(8,1, figsize = (8,24))
fig.suptitle('Histograms of Final Energies')

gamma = energy2gamma(source.energy)
kp = pp.k_p(stage.plasma_density)
k_beta = kp/np.sqrt(2*gamma)
sig_x_sq = source.emit_nx/k_beta/gamma
sig_y_sq = source.emit_ny/k_beta/gamma

energy_loss_beam = SI.e**2*stage.length/6/np.pi/SI.epsilon_0*(gamma*k_beta)**4*(sig_x_sq+sig_y_sq)  /SI.e/1e9

xlim = [7440,source.energy/1e9 + stage.nom_energy_gain/1e9 - energy_loss_beam+5]
Els = np.linspace(xlim[0],source.energy/1e9 + stage.nom_energy_gain/1e9 - energy_loss_beam, 1000)

for j, ax in enumerate(axs):
    ax.hist(list_of_E_ararys[j], bins =5, density = True, stacked = True)
    ax.plot(Els, rho(jitter_values[j],Els))
    ax.set_title(f'Jitter = {jitter_values[j]*1e6: .1f} $\mu m$')
    ax.set_xlim(xlim)
    ax.set_ylabel('Prob. Density')
    ax.grid()
axs[-1].set_xlabel('Final Energy (GeV)')
plt.tight_layout()
plt.subplots_adjust(top=0.95)

fig.savefig('Plots/Jitter/final_energy_histograms', bbox_inches = 'tight')
