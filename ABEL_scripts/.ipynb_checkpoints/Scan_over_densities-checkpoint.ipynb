# %%
import sys
sys.path.append('../../ABEL/')
from abel import *
import numpy as np
import time
import scipy.constants as SI 
import abel.utilities.plasma_physics as pp

# %load_ext autoreload
# %autoreload 2

# %%
# define driver
driver = SourceBasic()
driver.charge = -2.7e10 * SI.e # [C]
driver.energy = 31.25e9 # [eV]
driver.rel_energy_spread = 0.01
driver.bunch_length = 50e-6 # [m]
driver.z_offset = 580e-6 # [m]
driver.emit_nx, driver.emit_ny = 80e-6, 80e-6 # [m rad]
driver.beta_x, driver.beta_y = 5, 5 #30e-3, 30e-3 # [m]
driver.num_particles = 100000
driver.jitter.x = 0 # [m] 2e-6
driver.jitter.y = 0 # [m] 100e-9
driver.jitter.t = 0 # 10e-15 # [m]
driver.symmetrize = True
#drive_beam = driver.track()  # Convert a Source object to a Beam object.  ######


# define stage
stage = StageQuasistatic2d()
#stage = StagePrtclTransWakeInstability()                      #######
#stage.drive_beam = drive_beam                                 #######
stage.driver_source = driver
stage.length = 11 # [m]
stage.nom_energy_gain = 31.9e9/(11/stage.length) # [eV]
stage.plasma_density = 2e21 # [m^-3]
stage.ramp_beta_mag = 5
stage.radiation_reaction = True
stage.save_evolution = True
if stage.radiation_reaction == False:
    stage.save_evolution = False

# define first stage (half length)
first_stage = StageQuasistatic2d()
#first_stage = StagePrtclTransWakeInstability()                      #######
#first_stage.drive_beam = drive_beam                                 #######
first_stage.driver_source = driver
first_stage.nom_energy_gain = stage.nom_energy_gain/2
first_stage.length = stage.length/2
first_stage.plasma_density = stage.plasma_density
first_stage.ramp_beta_mag = stage.ramp_beta_mag
first_stage.radiation_reaction = stage.radiation_reaction
first_stage.save_evolution = stage.save_evolution

# define beam
source = SourceBasic()
source.charge = -1e10 * SI.e # [C]
source.energy = 5000e9 # [eV]
#source.rel_energy_spread = 0.1
#source.rel_energy_spread = 0.01
source.bunch_length = 10e-6 # [m]
source.z_offset = 0e-6 # [m]
source.emit_nx, source.emit_ny = 160e-6, 0.56e-6 # [m rad]
source.beta_x = stage.matched_beta_function(source.energy)
source.beta_y = source.beta_x
source.num_particles = 50000
source.jitter.t = driver.jitter.t
source.symmetrize = True
#beam = source.track()

"""
main_gamma = energy2gamma(source.energy)
main_sigma_x = np.sqrt(source.emit_nx/main_gamma*source.beta_x)  # [m]
main_sigma_y = np.sqrt(source.emit_ny/main_gamma*source.beta_y)  # [m]
source.x_offset = main_sigma_x*0.1  # [m]
source.y_offset = main_sigma_y*0.1  # [m]
"""
# define interstage
interstage = InterstageBasic()
#interstage = InterstageElegant()
interstage.beta0 = lambda E: stage.matched_beta_function(E)
interstage.dipole_length = lambda E: 1 * np.sqrt(E/10e9) # [m(eV)]
interstage.dipole_field = 1.  # [T]
#interstage.dipole_field = lambda E: np.min([1.0, 100e9/E]) # [T]

# beam delivery system
bds = BeamDeliverySystemBasic()
bds.beta_x, bds.beta_y = 8e-3, 0.4e-3 # [m]
bds.bunch_length = 0.75 * bds.beta_y

# define linac
linac = Linac()
linac.source = source
linac.stage = stage
#linac.first_stage = first_stage
linac.interstage = interstage
linac.num_stages = 1
shots = 1

# %%
# scan the driver timing jitter
energy_spread_values = np.logspace(-3,-1,8)
print(energy_spread_values)
linac.scan(f'scan_energy_spread_with_RR_{stage.radiation_reaction}', 
           lambda obj, val: setattr(obj.source, 'rel_energy_spread', val) or obj, 
           energy_spread_values,
           label='Relative energy spread [%]',
           scale=1e-2,
           num_shots_per_step=5, 
           parallel=False,
           overwrite=True);
# Out:
# [0.001      0.0019307  0.00372759 0.00719686 0.01389495 0.02682696
#  0.05179475 0.1       ]
# >> SHOT 1/40
# Tracking element 1 (SourceBasic, stage 0, s = 0.0 m, 5000.0 GeV, -1.60 nC, 0.1% rms, 160.9/0.6 µm-rad)
# Number of cores: 5
# time =  1.079254150390625  sec
# Tracking element 2 (StageQuasistatic2d, stage 1, s = 11.0 m, 5021.2 GeV, -1.60 nC, 0.2% rms, 160.3/0.6 µm-rad)
# >> SHOT 2/40
# Tracking element 1 (SourceBasic, stage 0, s = 0.0 m, 5000.0 GeV, -1.60 nC, 0.1% rms, 159.5/0.6 µm-rad)
# Number of cores: 5
# time =  1.0497591495513916  sec
# Tracking element 2 (StageQuasistatic2d, stage 1, s = 11.0 m, 5021.3 GeV, -1.60 nC, 0.2% rms, 159.0/0.6 µm-rad)
# >> SHOT 3/40
# Tracking element 1 (SourceBasic, stage 0, s = 0.0 m, 5000.0 GeV, -1.60 nC, 0.1% rms, 162.8/0.6 µm-rad)
# Number of cores: 5
# time =  1.0585196018218994  sec
# Tracking element 2 (StageQuasistatic2d, stage 1, s = 11.0 m, 5021.0 GeV, -1.60 nC, 0.2% rms, 162.3/0.6 µm-rad)
# >> SHOT 4/40
# Tracking element 1 (SourceBasic, stage 0, s = 0.0 m, 5000.0 GeV, -1.60 nC, 0.1% rms, 158.1/0.6 µm-rad)
# Number of cores: 5
# time =  1.0645205974578857  sec
# Tracking element 2 (StageQuasistatic2d, stage 1, s = 11.0 m, 5021.4 GeV, -1.60 nC, 0.2% rms, 157.5/0.6 µm-rad)
# >> SHOT 5/40
# Tracking element 1 (SourceBasic, stage 0, s = 0.0 m, 5000.1 GeV, -1.60 nC, 0.1% rms, 161.4/0.6 µm-rad)
# Number of cores: 5
# time =  1.0827407836914062  sec
# Tracking element 2 (StageQuasistatic2d, stage 1, s = 11.0 m, 5021.2 GeV, -1.60 nC, 0.2% rms, 160.9/0.6 µm-rad)
# >> SHOT 6/40
# Tracking element 1 (SourceBasic, stage 0, s = 0.0 m, 5000.0 GeV, -1.60 nC, 0.1% rms, 161.0/0.6 µm-rad)
# Number of cores: 5
# time =  1.1279053688049316  sec
# Tracking element 2 (StageQuasistatic2d, stage 1, s = 11.0 m, 5021.2 GeV, -1.60 nC, 0.2% rms, 160.5/0.6 µm-rad)
# >> SHOT 7/40
# Tracking element 1 (SourceBasic, stage 0, s = 0.0 m, 4999.9 GeV, -1.60 nC, 0.1% rms, 158.1/0.6 µm-rad)
# Number of cores: 5
# time =  1.049875259399414  sec
# Tracking element 2 (StageQuasistatic2d, stage 1, s = 11.0 m, 5021.3 GeV, -1.60 nC, 0.2% rms, 157.6/0.6 µm-rad)
# >> SHOT 8/40
# Tracking element 1 (SourceBasic, stage 0, s = 0.0 m, 5000.1 GeV, -1.60 nC, 0.1% rms, 159.7/0.6 µm-rad)
# Number of cores: 5
# time =  1.0622975826263428  sec
# Tracking element 2 (StageQuasistatic2d, stage 1, s = 11.0 m, 5021.4 GeV, -1.60 nC, 0.2% rms, 159.2/0.6 µm-rad)
# >> SHOT 9/40
# Tracking element 1 (SourceBasic, stage 0, s = 0.0 m, 5000.0 GeV, -1.60 nC, 0.1% rms, 160.3/0.6 µm-rad)
# Number of cores: 5
# time =  1.0908703804016113  sec
# Tracking element 2 (StageQuasistatic2d, stage 1, s = 11.0 m, 5021.2 GeV, -1.60 nC, 0.2% rms, 159.8/0.6 µm-rad)
# >> SHOT 10/40
# Tracking element 1 (SourceBasic, stage 0, s = 0.0 m, 5000.1 GeV, -1.60 nC, 0.1% rms, 161.9/0.6 µm-rad)
# Number of cores: 5
# time =  1.0892634391784668  sec
# Tracking element 2 (StageQuasistatic2d, stage 1, s = 11.0 m, 5021.2 GeV, -1.60 nC, 0.2% rms, 161.3/0.6 µm-rad)
# >> SHOT 11/40
# Tracking element 1 (SourceBasic, stage 0, s = 0.0 m, 5000.1 GeV, -1.60 nC, 0.1% rms, 160.9/0.6 µm-rad)
# Number of cores: 5
# time =  1.4541840553283691  sec
# Tracking element 2 (StageQuasistatic2d, stage 1, s = 11.0 m, 5021.3 GeV, -1.60 nC, 0.2% rms, 160.3/0.6 µm-rad)
# >> SHOT 12/40
# Tracking element 1 (SourceBasic, stage 0, s = 0.0 m, 5000.0 GeV, -1.60 nC, 0.1% rms, 159.9/0.6 µm-rad)
# Number of cores: 5
# time =  1.0790987014770508  sec
# Tracking element 2 (StageQuasistatic2d, stage 1, s = 11.0 m, 5021.2 GeV, -1.60 nC, 0.2% rms, 159.3/0.6 µm-rad)
# >> SHOT 13/40
# Tracking element 1 (SourceBasic, stage 0, s = 0.0 m, 5000.0 GeV, -1.60 nC, 0.1% rms, 160.3/0.6 µm-rad)
# Number of cores: 5
# time =  1.0900707244873047  sec
# Tracking element 2 (StageQuasistatic2d, stage 1, s = 11.0 m, 5021.2 GeV, -1.60 nC, 0.2% rms, 159.8/0.6 µm-rad)
# >> SHOT 14/40
# Tracking element 1 (SourceBasic, stage 0, s = 0.0 m, 5000.0 GeV, -1.60 nC, 0.1% rms, 158.7/0.6 µm-rad)
# Number of cores: 5
# time =  1.0579721927642822  sec
# Tracking element 2 (StageQuasistatic2d, stage 1, s = 11.0 m, 5021.5 GeV, -1.60 nC, 0.2% rms, 158.2/0.6 µm-rad)
# >> SHOT 15/40
# Tracking element 1 (SourceBasic, stage 0, s = 0.0 m, 5000.0 GeV, -1.60 nC, 0.1% rms, 160.1/0.5 µm-rad)
# Number of cores: 5
# time =  1.0633361339569092  sec
# Tracking element 2 (StageQuasistatic2d, stage 1, s = 11.0 m, 5021.3 GeV, -1.60 nC, 0.2% rms, 159.6/0.5 µm-rad)
# >> SHOT 16/40
# Tracking element 1 (SourceBasic, stage 0, s = 0.0 m, 5000.1 GeV, -1.60 nC, 0.1% rms, 157.7/0.6 µm-rad)
# Number of cores: 5
# time =  1.093562364578247  sec
# Tracking element 2 (StageQuasistatic2d, stage 1, s = 11.0 m, 5021.5 GeV, -1.60 nC, 0.2% rms, 157.2/0.6 µm-rad)
# >> SHOT 17/40
# Tracking element 1 (SourceBasic, stage 0, s = 0.0 m, 5000.0 GeV, -1.60 nC, 0.1% rms, 158.7/0.6 µm-rad)
# Number of cores: 5
# time =  1.084254264831543  sec
# Tracking element 2 (StageQuasistatic2d, stage 1, s = 11.0 m, 5021.3 GeV, -1.60 nC, 0.2% rms, 158.2/0.6 µm-rad)
# >> SHOT 18/40
# Tracking element 1 (SourceBasic, stage 0, s = 0.0 m, 5000.0 GeV, -1.60 nC, 0.1% rms, 156.7/0.6 µm-rad)
# Number of cores: 5
# time =  1.0792996883392334  sec
# Tracking element 2 (StageQuasistatic2d, stage 1, s = 11.0 m, 5021.6 GeV, -1.60 nC, 0.2% rms, 156.2/0.6 µm-rad)
# >> SHOT 19/40
# Tracking element 1 (SourceBasic, stage 0, s = 0.0 m, 5000.1 GeV, -1.60 nC, 0.1% rms, 159.3/0.6 µm-rad)
# Number of cores: 5
# time =  1.0658557415008545  sec
# Tracking element 2 (StageQuasistatic2d, stage 1, s = 11.0 m, 5021.4 GeV, -1.60 nC, 0.2% rms, 158.7/0.6 µm-rad)
# >> SHOT 20/40
# Tracking element 1 (SourceBasic, stage 0, s = 0.0 m, 5000.1 GeV, -1.60 nC, 0.1% rms, 157.2/0.6 µm-rad)
# Number of cores: 5
# time =  1.0626842975616455  sec
# Tracking element 2 (StageQuasistatic2d, stage 1, s = 11.0 m, 5021.6 GeV, -1.60 nC, 0.2% rms, 156.7/0.6 µm-rad)
# >> SHOT 21/40
# Tracking element 1 (SourceBasic, stage 0, s = 0.0 m, 4999.9 GeV, -1.60 nC, 0.1% rms, 160.2/0.6 µm-rad)
# Number of cores: 5
# time =  1.0990321636199951  sec
# Tracking element 2 (StageQuasistatic2d, stage 1, s = 11.0 m, 5021.2 GeV, -1.60 nC, 0.2% rms, 159.7/0.6 µm-rad)
# >> SHOT 22/40
# Tracking element 1 (SourceBasic, stage 0, s = 0.0 m, 5000.1 GeV, -1.60 nC, 0.1% rms, 159.3/0.6 µm-rad)
# Number of cores: 5
# time =  1.112123966217041  sec
# Tracking element 2 (StageQuasistatic2d, stage 1, s = 11.0 m, 5021.4 GeV, -1.60 nC, 0.2% rms, 158.8/0.6 µm-rad)
# >> SHOT 23/40
# Tracking element 1 (SourceBasic, stage 0, s = 0.0 m, 5000.0 GeV, -1.60 nC, 0.1% rms, 158.9/0.6 µm-rad)
# Number of cores: 5
# time =  1.2866888046264648  sec
# Tracking element 2 (StageQuasistatic2d, stage 1, s = 11.0 m, 5021.4 GeV, -1.60 nC, 0.2% rms, 158.4/0.6 µm-rad)
# >> SHOT 24/40
# Tracking element 1 (SourceBasic, stage 0, s = 0.0 m, 5000.0 GeV, -1.60 nC, 0.1% rms, 159.9/0.6 µm-rad)
# Number of cores: 5
# time =  1.278754472732544  sec
# Tracking element 2 (StageQuasistatic2d, stage 1, s = 11.0 m, 5021.2 GeV, -1.60 nC, 0.2% rms, 159.4/0.6 µm-rad)
# >> SHOT 25/40
# Tracking element 1 (SourceBasic, stage 0, s = 0.0 m, 5000.0 GeV, -1.60 nC, 0.1% rms, 158.5/0.6 µm-rad)
# Number of cores: 5
# time =  1.1873927116394043  sec
# Tracking element 2 (StageQuasistatic2d, stage 1, s = 11.0 m, 5021.4 GeV, -1.60 nC, 0.2% rms, 158.0/0.6 µm-rad)
# >> SHOT 26/40
# Tracking element 1 (SourceBasic, stage 0, s = 0.0 m, 5000.0 GeV, -1.60 nC, 0.1% rms, 157.5/0.6 µm-rad)
# Number of cores: 5
# time =  1.1335818767547607  sec
# Tracking element 2 (StageQuasistatic2d, stage 1, s = 11.0 m, 5021.5 GeV, -1.60 nC, 0.2% rms, 157.0/0.6 µm-rad)
# >> SHOT 27/40
# Tracking element 1 (SourceBasic, stage 0, s = 0.0 m, 5000.0 GeV, -1.60 nC, 0.1% rms, 159.1/0.6 µm-rad)
# Number of cores: 5
# time =  1.1610000133514404  sec
# Tracking element 2 (StageQuasistatic2d, stage 1, s = 11.0 m, 5021.3 GeV, -1.60 nC, 0.2% rms, 158.5/0.6 µm-rad)
# >> SHOT 28/40
# Tracking element 1 (SourceBasic, stage 0, s = 0.0 m, 5000.1 GeV, -1.60 nC, 0.1% rms, 158.0/0.6 µm-rad)
# Number of cores: 5
# time =  1.1169257164001465  sec
# Tracking element 2 (StageQuasistatic2d, stage 1, s = 11.0 m, 5021.4 GeV, -1.60 nC, 0.2% rms, 157.5/0.6 µm-rad)
# >> SHOT 29/40
# Tracking element 1 (SourceBasic, stage 0, s = 0.0 m, 5000.0 GeV, -1.60 nC, 0.1% rms, 161.6/0.6 µm-rad)
# Number of cores: 5
# time =  1.0413322448730469  sec
# Tracking element 2 (StageQuasistatic2d, stage 1, s = 11.0 m, 5021.1 GeV, -1.60 nC, 0.2% rms, 161.1/0.6 µm-rad)
# >> SHOT 30/40
# Tracking element 1 (SourceBasic, stage 0, s = 0.0 m, 5000.0 GeV, -1.60 nC, 0.1% rms, 160.5/0.6 µm-rad)
# Number of cores: 5
# time =  1.043900966644287  sec
# Tracking element 2 (StageQuasistatic2d, stage 1, s = 11.0 m, 5021.2 GeV, -1.60 nC, 0.2% rms, 160.0/0.6 µm-rad)
# >> SHOT 31/40
# Tracking element 1 (SourceBasic, stage 0, s = 0.0 m, 5000.0 GeV, -1.60 nC, 0.1% rms, 161.1/0.6 µm-rad)
# Number of cores: 5
# time =  1.0847172737121582  sec
# Tracking element 2 (StageQuasistatic2d, stage 1, s = 11.0 m, 5021.2 GeV, -1.60 nC, 0.2% rms, 160.6/0.6 µm-rad)
# >> SHOT 32/40
# Tracking element 1 (SourceBasic, stage 0, s = 0.0 m, 5000.0 GeV, -1.60 nC, 0.1% rms, 163.6/0.6 µm-rad)
# Number of cores: 5
# time =  1.071486234664917  sec
# Tracking element 2 (StageQuasistatic2d, stage 1, s = 11.0 m, 5021.2 GeV, -1.60 nC, 0.2% rms, 163.0/0.6 µm-rad)
# >> SHOT 33/40
# Tracking element 1 (SourceBasic, stage 0, s = 0.0 m, 5000.0 GeV, -1.60 nC, 0.1% rms, 159.8/0.6 µm-rad)
# Number of cores: 5
# time =  1.063030481338501  sec
# Tracking element 2 (StageQuasistatic2d, stage 1, s = 11.0 m, 5021.4 GeV, -1.60 nC, 0.2% rms, 159.3/0.6 µm-rad)
# >> SHOT 34/40
# Tracking element 1 (SourceBasic, stage 0, s = 0.0 m, 5000.0 GeV, -1.60 nC, 0.1% rms, 159.0/0.6 µm-rad)
# Number of cores: 5
# time =  1.1011710166931152  sec
# Tracking element 2 (StageQuasistatic2d, stage 1, s = 11.0 m, 5021.4 GeV, -1.60 nC, 0.2% rms, 158.5/0.6 µm-rad)
# >> SHOT 35/40
# Tracking element 1 (SourceBasic, stage 0, s = 0.0 m, 5000.1 GeV, -1.60 nC, 0.1% rms, 160.2/0.6 µm-rad)
# Number of cores: 5
# time =  1.202526569366455  sec
# Tracking element 2 (StageQuasistatic2d, stage 1, s = 11.0 m, 5021.4 GeV, -1.60 nC, 0.2% rms, 159.7/0.6 µm-rad)
# >> SHOT 36/40
# Tracking element 1 (SourceBasic, stage 0, s = 0.0 m, 5000.0 GeV, -1.60 nC, 0.1% rms, 162.0/0.6 µm-rad)
# Number of cores: 5
# time =  1.0910892486572266  sec
# Tracking element 2 (StageQuasistatic2d, stage 1, s = 11.0 m, 5021.2 GeV, -1.60 nC, 0.2% rms, 161.5/0.6 µm-rad)
# >> SHOT 37/40
# Tracking element 1 (SourceBasic, stage 0, s = 0.0 m, 5000.0 GeV, -1.60 nC, 0.1% rms, 158.9/0.6 µm-rad)
# Number of cores: 5
# time =  1.0800926685333252  sec
# Tracking element 2 (StageQuasistatic2d, stage 1, s = 11.0 m, 5021.4 GeV, -1.60 nC, 0.2% rms, 158.4/0.6 µm-rad)
# >> SHOT 38/40
# Tracking element 1 (SourceBasic, stage 0, s = 0.0 m, 5000.0 GeV, -1.60 nC, 0.1% rms, 158.2/0.6 µm-rad)
# Number of cores: 5
# time =  1.0477323532104492  sec
# Tracking element 2 (StageQuasistatic2d, stage 1, s = 11.0 m, 5021.3 GeV, -1.60 nC, 0.2% rms, 157.7/0.6 µm-rad)
# >> SHOT 39/40
# Tracking element 1 (SourceBasic, stage 0, s = 0.0 m, 5000.0 GeV, -1.60 nC, 0.1% rms, 158.1/0.6 µm-rad)
# Number of cores: 5
# time =  1.0630266666412354  sec
# Tracking element 2 (StageQuasistatic2d, stage 1, s = 11.0 m, 5021.3 GeV, -1.60 nC, 0.2% rms, 157.6/0.6 µm-rad)
# >> SHOT 40/40
# Tracking element 1 (SourceBasic, stage 0, s = 0.0 m, 5000.0 GeV, -1.60 nC, 0.1% rms, 157.4/0.6 µm-rad)
# Number of cores: 5
# time =  1.071495532989502  sec
# Tracking element 2 (StageQuasistatic2d, stage 1, s = 11.0 m, 5021.4 GeV, -1.60 nC, 0.2% rms, 156.9/0.6 µm-rad)

# %%
linac.plot_beam_function(Beam.rel_energy_spread, label='Energy spread (%)', scale=1e-2, xscale='log')
