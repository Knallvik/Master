# %%
import sys
sys.path.append('../')
from abel import *
# %load_ext autoreload
# %autoreload 2
#from abel.classes.stage.impl import stage_quasistatic_2d_radiation_reaction as rr
import numpy as np
import matplotlib.pyplot as plt
#from abel.utilities.statistics import prct_clean, prct_clean2d
#from matplotlib.animation import FuncAnimation
import time

# %%
# define driver
driver = SourceBasic()
driver.charge = -2.7e10 * SI.e # [C]
driver.energy = 31.25e9 # [eV]
driver.rel_energy_spread = 0.01
driver.bunch_length = 50e-6 # [m]
driver.z_offset = 580e-6 # [m]
driver.emit_nx, driver.emit_ny = 80e-6, 80e-6 # [m rad]
driver.beta_x, driver.beta_y = 5, 5 #30e-3, 30e-3 [m]
driver.num_particles = 100000
driver.jitter.x = 0 # [m] 2e-6
driver.jitter.y = 0 # [m] 100e-9
driver.jitter.t = 0 #10e-15 # [m]
driver.symmetrize = True

# define stage
stage = StageHipace()
stage.driver_source = driver
stage.length = 11 # [m]
stage.plasma_density = 2e21 # [m^-3]
stage.nom_energy_gain = 31.9e9/(11/stage.length) # [eV]
stage.radiation_reaction = True
stage.ion_motion = False
stage.beam_ionization=False
stage.ramp_beta_mag = 5
stage.num_nodes = 13

# define first stage (half length)
#first_stage = StageHipace()
#first_stage.driver_source = driver
#first_stage.length = stage.length/2 # [m]
#first_stage.plasma_density = 2e21 # [m^-3]
#first_stage.nom_energy_gain = stage.nom_energy_gain/2 # [eV]
#first_stage.radiation_reaction = stage.radiation_reaction

# define beam
source = SourceBasic()
source.charge = -1e10 * SI.e # [C]
source.energy = 470e9 # [eV]
source.rel_energy_spread = 0.01
source.bunch_length = 28e-6 # [m]
source.z_offset = 0e-6 # [m]
source.emit_nx, source.emit_ny = 160e-6, 0.56e-6 # [m rad]
source.beta_x = stage.matched_beta_function(source.energy)
source.beta_y = source.beta_x
source.num_particles = 10000
source.jitter.t = driver.jitter.t

source1 = SourceBasic()
source1.charge = -1 * SI.e # [C]
source1.energy = 470e9 # [eV]
source1.rel_energy_spread = 0
source1.bunch_length = 0 # [m]
source1.z_offset = 0e-6 # [m]
source1.x_offset = 0e-6
source1.y_offset = 0e-6
#source1.emit_nx, source.emit_ny = 160e-6, 0.56e-6 # [m rad]
#source1.beta_x = stage.matched_beta_function(source.energy)
#source1.beta_y = source.beta_x
source1.num_particles = 1
source1.jitter.t = driver.jitter.t

# define interstage
interstage = InterstageBasic()
interstage.beta0 = lambda E: stage.matched_beta_function(E)
interstage.dipole_length = lambda E: 1 * np.sqrt(E/10e9) # [m(eV)]
interstage.dipole_field = 1 # [T]

# beam delivery system
bds = BeamDeliverySystemBasic()
bds.beta_x, bds.beta_y = 8e-3, 0.4e-3 # [m]
bds.bunch_length = 0.75 * bds.beta_y

# define linac
linac = Linac()
linac.source = source + source1
linac.stage = stage
#linac.first_stage = first_stage
linac.interstage = interstage
linac.num_stages = 1
shots = 1

# %%
name = f'linac_hipace_{int(source.energy/1e9)}GeV_\1_particle_\
{interstage.dipole_field}T_ex_{source.emit_nx*1e6}_jitterx_{driver.jitter.x}_\
jittery_{driver.jitter.y}_RR_{stage.radiation_reaction}N_{linac.num_stages}_11m_{shots}_shot'

linac.run(name, num_shots=shots, overwrite=False, parallel=False);
# Out:
# /pfs/lustrep2/scratch/project_465000445/kalvik/thesis_scripts/ABEL_dev/abel/classes/beam.py:289: RuntimeWarning: Degrees of freedom <= 0 for slice
#   return np.sqrt(np.linalg.det(np.cov(xs, uxs/SI.c)))
# /pfs/lustrep2/scratch/project_465000445/kalvik/master_kalvik/lib/python3.9/site-packages/numpy/lib/function_base.py:2705: RuntimeWarning: divide by zero encountered in divide
#   c *= np.true_divide(1, fact)
# /pfs/lustrep2/scratch/project_465000445/kalvik/master_kalvik/lib/python3.9/site-packages/numpy/lib/function_base.py:2705: RuntimeWarning: invalid value encountered in multiply
#   c *= np.true_divide(1, fact)
# /pfs/lustrep2/scratch/project_465000445/kalvik/master_kalvik/lib/python3.9/site-packages/numpy/linalg/linalg.py:2139: RuntimeWarning: invalid value encountered in det
#   r = _umath_linalg.det(a, signature=signature)
# /pfs/lustrep2/scratch/project_465000445/kalvik/thesis_scripts/ABEL_dev/abel/classes/beam.py:293: RuntimeWarning: Degrees of freedom <= 0 for slice
#   return np.sqrt(np.linalg.det(np.cov(ys, uys/SI.c)))
# Tracking element 1 (SourceBasic, stage 0, s = 0.0 m, 470.0 GeV, -0.00 nC, 0.0% rms, nan/nan µm-rad)
# Running job 5349228
# >> Starting (0:00)
# >> Starting (0:00)
# >> Starting (0:00)
# >> Starting (0:00)
# >> Starting (0:00)
# >> Starting (0:00)
# >> Starting (0:00)
# >> Running (0:06)
# >> Running (0:16)
# >> Running (0:26)
# >> Running (0:36)
# >> Running (0:47)
# >> Running (0:57)
# >> Running (1:07)
# >> Running (1:17)
# >> Running (1:27)
# >> Running (1:37)
# >> Running (1:47)
# >> Running (1:57)
# >> Running (2:07)
# >> Running (2:17)
# >> Running (2:27)
# >> Running (2:37)
# >> Running (2:47)
# >> Running (2:57)
# >> Running (3:08)
# >> Running (3:18)
# >> Running (3:28)
# >> Running (3:38)
# >> Running (3:48)
# >> Running (3:58)
# >> Ending (4:06)
# HDF5-DIAG: Error detected in HDF5 (1.12.2) thread 0:
#   #000: H5F.c line 620 in H5Fopen(): unable to open file
#     major: File accessibility
#     minor: Unable to open file
#   #001: H5VLcallback.c line 3501 in H5VL_file_open(): failed to iterate over available VOL connector plugins
#     major: Virtual Object Layer
#     minor: Iteration failed
#   #002: H5PLpath.c line 578 in H5PL__path_table_iterate(): can't iterate over plugins in plugin path '(null)'
#     major: Plugin for dynamically loaded library
#     minor: Iteration failed
#   #003: H5PLpath.c line 620 in H5PL__path_table_iterate_process_path(): can't open directory: /usr/local/hdf5/lib/plugin
#     major: Plugin for dynamically loaded library
#     minor: Can't open directory or file
#   #004: H5VLcallback.c line 3351 in H5VL__file_open(): open failed
#     major: Virtual Object Layer
#     minor: Can't open object
#   #005: H5VLnative_file.c line 97 in H5VL__native_file_open(): unable to open file
#     major: File accessibility
#     minor: Unable to open file
#   #006: H5Fint.c line 1834 in H5F_open(): unable to open file: name = 'run_data/temp/0608b2f7-6fc7-4414-8724-fcd54de6370b/diags/hdf5/openpmd_007488.h5', tent_flags = 0
#     major: File accessibility
#     minor: Unable to open file
#   #007: H5FD.c line 723 in H5FD_open(): open failed
#     major: Virtual File Layer
#     minor: Unable to initialize object
#   #008: H5FDsec2.c line 352 in H5FD__sec2_open(): unable to open file: name = 'run_data/temp/0608b2f7-6fc7-4414-8724-fcd54de6370b/diags/hdf5/openpmd_007488.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0
#     major: File accessibility
#     minor: Unable to open file
# [AbstractIOHandlerImpl] IO Task OPEN_FILE failed with exception. Clearing IO queue and passing on the exception.
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# Cell In[3], line 5
#       1 name = f'linac_hipace_{int(source.energy/1e9)}GeV_\1_particle_\
#       2 {interstage.dipole_field}T_ex_{source.emit_nx*1e6}_jitterx_{driver.jitter.x}_\
#       3 jittery_{driver.jitter.y}_RR_{stage.radiation_reaction}N_{linac.num_stages}_11m_{shots}_shot'
# ----> 5 linac.run(name, num_shots=shots, overwrite=False, parallel=False);
#
# File /pfs/lustrep2/scratch/project_465000445/kalvik/thesis_scripts/ABEL_dev/abel/classes/runnable.py:50, in Runnable.run(self, run_name, num_shots, savedepth, verbose, overwrite, parallel, max_cores)
#      46 else:
#      47
#      48     # perform in-series tracking
#      49     for shot in range(num_shots):
# ---> 50         self.perform_shot(shot)
#      52 # return final beam from first shot
#      53 self.__dict__.update(self[0].__dict__)
#
# File /pfs/lustrep2/scratch/project_465000445/kalvik/thesis_scripts/ABEL_dev/abel/classes/runnable.py:83, in Runnable.perform_shot(self, shot)
#      80     print('>> SHOT ' + str(shot+1) + '/' + str(self.num_shots), flush=True)
#      82 #if overwrite_from is None: # TODO
# ---> 83 beam = self.track(beam=None, savedepth=self.savedepth, runnable=self, verbose=self.verbose)
#      85 # save object to file
#      86 self.save()
#
# File /pfs/lustrep2/scratch/project_465000445/kalvik/thesis_scripts/ABEL_dev/abel/classes/beamline/beamline.py:36, in Beamline.track(self, beam, savedepth, runnable, verbose)
#      34 # perform element-wise tracking
#      35 for trackable in self.trackables:
# ---> 36     beam = trackable.track(beam, savedepth-1, runnable, verbose)
#      38 return beam
#
# File /pfs/lustrep2/scratch/project_465000445/kalvik/thesis_scripts/ABEL_dev/abel/classes/stage/impl/stage_hipace.py:132, in StageHipace.track(self, beam0, savedepth, runnable, verbose)
#     129 hipace_write_jobscript(filename_job_script, filename_input, num_nodes=self.num_nodes)
#     131 # run HiPACE++
# --> 132 beam, driver = hipace_run(filename_job_script, self.num_steps)
#     134 # !! QUICK FIX: TODO to make this a real ramp
#     135 # apply plasma-density down ramp (magnify beta function)
#     136 beam.magnify_beta_function(self.ramp_beta_mag, axis_defining_beam=driver0)
#
# File /pfs/lustrep2/scratch/project_465000445/kalvik/thesis_scripts/ABEL_dev/abel/apis/hipace/hipace_api.py:120, in hipace_run(filename_job_script, num_steps, runfolder, quiet)
#     118 # when finished, load the beam and driver
#     119 filename = runfolder + "diags/hdf5/openpmd_{:06}.h5".format(int(num_steps))
# --> 120 beam = Beam.load(filename, beam_name='beam')
#     121 driver = Beam.load(filename, beam_name='driver')
#     123 return beam, driver
#
# File /pfs/lustrep2/scratch/project_465000445/kalvik/thesis_scripts/ABEL_dev/abel/classes/beam.py:692, in Beam.load(_, filename, beam_name)
#     688 @classmethod
#     689 def load(_, filename, beam_name='beam'):
#     690
#     691     # load file
# --> 692     series = io.Series(filename, io.Access.read_only)
#     694     # find index (use last one)
#     695     *_, index = series.iterations
#
# Error: Read Error in backend HDF5
# Object type:	File
# Error type:	Inaccessible
# Further description:	Failed to open HDF5 file run_data/temp/0608b2f7-6fc7-4414-8724-fcd54de6370b/diags/hdf5/openpmd_007488.h5

# %%
save = True
linac.plot_survey()

linac.stages[0].plot_wakefield()
linac.stages[0].plot_wake()

linac.stages[0].plot_evolution()

# plot beam evolution
fig_9GeV = linac.plot_evolution()
if save:
    fig_9GeV.savefig(f'Plots_with_updated_params/Hipace_1_particle_\
    {shots}_shots_{int(source.energy/1e9)}GeV_{int(source.emit_nx*1e6)}\
    mmmrad_{int(source.emit_ny*1e6)}\
    mmmrad_{interstage.dipole_field}T_RR_{stage.radiation_reaction}_\
    B_{interstage.dipole_field}T_11m.png')

linac.plot_waterfalls()

# %%
linac.final_beam().plot_lps()

linac.final_beam().plot_trace_space_x()
linac.final_beam().plot_trace_space_y()

# %%
#Get average energy of the beam
beam_ = linac.get_beam(0)
E = beam_.energy()
print(E/1e9)
